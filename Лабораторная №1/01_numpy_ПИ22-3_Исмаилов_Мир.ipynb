# %% [markdown]
# # Numpy

# %% [markdown]
# Материалы:
# * Макрушин С.В. "Лекция 1: Библиотека Numpy"
# * https://numpy.org/doc/stable/user/index.html
# * https://numpy.org/doc/stable/reference/index.html

# %% [markdown]
# ## Задачи для совместного разбора

# %% [markdown]
# 1. Сгенерировать двухмерный массив `arr` размерности (4, 7), состоящий из случайных действительных чисел, равномерно распределенных в диапазоне от 0 до 20. Нормализовать значения массива с помощью преобразования вида  $𝑎𝑥+𝑏$  так, что после нормализации максимальный элемент масcива будет равен 1.0, минимальный 0.0

# %%
import numpy as np

# %%
import random
arr = np.random.uniform(0, 20, 28).reshape(4,7)
print("Матрица: \n", arr)
norm_vid = (arr - np.min(arr)) / (np.max(arr) - np.min(arr))
print("Норм матрица: \n", norm_vid)
# Out:
# Матрица:
#  [[14.65832816 14.29725534 11.18417842 18.60351637 12.74360736 14.76213099
#    2.88794803]
#  [ 6.97369296  7.37809697  8.21371966 10.89474552 18.82172912  6.23998186
#   17.13637636]
#  [11.15649377 14.47670065  2.9533678   7.21621241  9.06900447  3.87031571
#   12.8304267 ]
#  [16.26473671  6.96229153  8.52664443  7.83601606  8.79422903 14.52056945
#   17.65790454]]
# Норм матрица:
#  [[0.73870603 0.71604519 0.52066928 0.98630502 0.61853864 0.74522067
#   0.        ]
#  [0.2564203  0.28180059 0.33424406 0.50250455 1.         0.21037278
#   0.89422769]
#  [0.5189318  0.72730713 0.00410573 0.27164076 0.38792151 0.06165314
#   0.6239874 ]
#  [0.83952381 0.25570475 0.35388313 0.31053948 0.37067668 0.73006033
#   0.92695867]]

# %% [markdown]
# 2. Создать матрицу 8 на 10 из случайных целых (используя модуль `numpy.random`) чисел из диапозона от 0 до 10 и найти в ней строку (ее индекс и вывести саму строку), в которой сумма значений минимальна.

# %%
arr = np.random.randint(0, 10, size = (8, 10))
print("Матрица: \n", arr)
min_str = min((r for r in arr), key = sum)
print("Строка с наименьшей суммой чисел: \n", min_str)
# Out:
# Матрица:
#  [[6 0 4 3 5 0 9 0 0 6]
#  [4 4 0 7 7 8 7 2 6 7]
#  [5 0 6 9 0 2 8 3 3 8]
#  [0 2 9 1 6 3 0 8 3 8]
#  [8 9 1 5 7 2 4 5 9 7]
#  [2 7 5 3 2 5 8 3 2 8]
#  [6 9 6 6 1 0 3 3 5 3]
#  [8 2 7 2 8 8 4 5 2 3]]
# Строка с наименьшей суммой чисел:
#  [6 0 4 3 5 0 9 0 0 6]

# %% [markdown]
# 3. Найти евклидово расстояние между двумя одномерными векторами одинаковой размерности.

# %%
a = np.array((0, 0, 0))
b = np.array((3, 3, 3))
dis = np.linalg.norm(a-b)
print(dis)
# Out:
# 5.196152422706632

# %% [markdown]
# 4. Решить матричное уравнение `A*X*B=-C` - найти матрицу `X`. Где `A = [[-1, 2, 4], [-3, 1, 2], [-3, 0, 1]]`, `B=[[3, -1], [2, 1]]`, `C=[[7, 21], [11, 8], [8, 4]]`.

# %%
A = np.array([[-1, 2, 4], [-3, 1, 2], [-3, 0, 1]])
B = np.array([[3, -1], [2, 1]])
C = np.array([[7, 21], [11, 8], [8, 4]])
Ai = np.linalg.inv(A)
Bi = np.linalg.inv(B)
C1 = C*(-1)
res1 = np.dot(C1, Bi)
res2 = np.dot(Ai, res1)
print(np.around(res2))
# Out:
# [[ 1.  0.]
#  [-2.  1.]
#  [ 3. -4.]]

# %% [markdown]
# ## Лабораторная работа №1

# %% [markdown]
# Замечание: при решении данных задач не подразумевается использования циклов или генераторов Python, если в задании не сказано обратного. Решение должно опираться на использования функционала библиотеки `numpy`.

# %% [markdown]
# 1. Файл `minutes_n_ingredients.csv` содержит информацию об идентификаторе рецепта, времени его выполнения в минутах и количестве необходимых ингредиентов. Считайте данные из этого файла в виде массива `numpy` типа `int32`, используя `np.loadtxt`. Выведите на экран первые 5 строк массива.

# %%
import numpy as np
stroki = np.loadtxt('minutes_n_ingredients.csv', dtype = 'int32', delimiter = ',', skiprows = 1)
print(stroki[:5])
# Out:
# [[127244     60     16]
#  [ 23891     25      7]
#  [ 94746     10      6]
#  [ 67660      5      6]
#  [157911     60     14]]

# %% [markdown]
# 2. Вычислите среднее значение, минимум, максимум и медиану по каждому из столбцов, кроме первого.

# %%
print("Среднее значение: ", np.mean(stroki[:, 1:], 0))
print("Максимальное значение: ", np.max(stroki[:, 1:], 0))
print("Минимальное значение: ", np.min(stroki[:, 1:], 0))
print("Медиана: ", np.median(stroki[:, 1:], 0))
# Out:
# Среднее значение:  [2.16010017e+04 9.05528000e+00]
# Максимальное значение:  [2147483647         39]
# Минимальное значение:  [0 1]
# Медиана:  [40.  9.]

# %% [markdown]
# 3. Ограничьте сверху значения продолжительности выполнения рецепта значением квантиля $q_{0.75}$.

# %%
tm = np.quantile(stroki[:,1], 0.75)
print(tm)
# Out:
# 65.0

# %% [markdown]
# 4. Посчитайте, для скольких рецептов указана продолжительность, равная нулю. Замените для таких строк значение в данном столбце на 1.

# %%
nz = np.count_nonzero(stroki[:,1] == 0)
print(nz)
stroki[stroki[:,1]==0] = 1
print(np.count_nonzero(stroki[:,1] == 0))
# Out:
# 0
# 0

# %% [markdown]
# 5. Посчитайте, сколько уникальных рецептов находится в датасете.

# %%
un = np.unique(stroki[:, 0])
print(len(un))
# Out:
# 99522

# %% [markdown]
# 6. Сколько и каких различных значений кол-ва ингредиентов присутвует в рецептах из датасета?

# %%
u, n = np.unique(stroki[:,2], return_counts=True)
print(np.column_stack((u, n)))
# Out:
# [[    1   492]
#  [    2   924]
#  [    3  2884]
#  [    4  5479]
#  [    5  7874]
#  [    6  9328]
#  [    7 10579]
#  [    8 10887]
#  [    9 10542]
#  [   10  9548]
#  [   11  8262]
#  [   12  6574]
#  [   13  4985]
#  [   14  3639]
#  [   15  2583]
#  [   16  1760]
#  [   17  1237]
#  [   18   787]
#  [   19   566]
#  [   20   376]
#  [   21   214]
#  [   22   161]
#  [   23   105]
#  [   24    68]
#  [   25    50]
#  [   26    28]
#  [   27    16]
#  [   28    16]
#  [   29    12]
#  [   30    12]
#  [   31     3]
#  [   32     1]
#  [   33     2]
#  [   34     1]
#  [   35     3]
#  [   37     1]
#  [   39     1]]

# %% [markdown]
# 7. Создайте версию массива, содержащую информацию только о рецептах, состоящих не более чем из 5 ингредиентов.

# %%
a = stroki[stroki[:,2]<=5]
na = np.copy(a)
print(na)
print('\n\n',stroki)
# Out:
# [[446597     15      5]
#  [204134      5      3]
#  [ 25623      6      4]
#  ...
#  [ 52088     60      5]
#  [128811     15      4]
#  [370915      5      4]]
#
#
#  [[127244     60     16]
#  [ 23891     25      7]
#  [ 94746     10      6]
#  ...
#  [498432     65     15]
#  [370915      5      4]
#  [ 81993    140     14]]

# %% [markdown]
# 8. Для каждого рецепта посчитайте, сколько в среднем ингредиентов приходится на одну минуту рецепта. Найдите максимальное значение этой величины для всего датасета

# %%
mi = stroki[:,2]/stroki[:,1]
print('Количество ингридиентов: \n', mi)
print('Максимальное значение: \n', max(mi))
# Out:
# Количество ингридиентов:
#  [0.26666667 0.28       0.6        ... 0.23076923 0.8        0.1       ]
# Максимальное значение:
#  23.0

# %% [markdown]
# 9. Вычислите среднее количество ингредиентов для топ-100 рецептов с наибольшей продолжительностью

# %%
length_top_100_indexes = stroki[:,1].argsort()
length_top_100 = stroki[length_top_100_indexes][-100:]
print('Топ-100 рецептов с наибольшей продолжительностью\n', length_top_100)
print('Среднее кол-во ингридиентов для топ-100 рецептов\n', np.mean(length_top_100[:,2], axis = 0))
# Out:
# Топ-100 рецептов с наибольшей продолжительностью
#  [[    116645      10095          6]
#  [    252450      10100          4]
#  [     89339      10105          8]
#  [    369728      10110          7]
#  [    417539      10110          6]
#  [    199925      10140          7]
#  [    258854      10320         13]
#  [     55411      10320          8]
#  [     57721      10440         12]
#  [    106876      11520          8]
#  [    116809      11521          3]
#  [    164029      11550         14]
#  [    298229      11565          8]
#  [     64793      14405          3]
#  [    230796      14420          8]
#  [    453387      14420          8]
#  [    269245      14425          5]
#  [    266032      14430          8]
#  [     26995      14450         17]
#  [    233539      14460         10]
#  [    197469      14460         13]
#  [    443929      15880          5]
#  [     30101      15900          5]
#  [     13904      17310          8]
# ...

# %% [markdown]
# 10. Выберите случайным образом и выведите информацию о 10 различных рецептах

# %%
indexes = np.random.randint(stroki.shape[0], size = 10)
print(stroki[indexes])
# Out:
# [[233215    105     12]
#  [328000     55      5]
#  [329579     55     18]
#  [ 54243      5      7]
#  [ 24720     55     14]
#  [386431     20     10]
#  [174524     10      9]
#  [201489    270     10]
#  [386473    210     12]
#  [161364     85     17]]

# %% [markdown]
# 11. Выведите процент рецептов, кол-во ингредиентов в которых меньше среднего.

# %%
meann = np.mean(stroki[:,2], axis = 0)
print(stroki[stroki[:,2]<meann])
print('Процент рецептов, кол-во ингредиентов в которых меньше среднего')
print((100*len(stroki[stroki[:,2]<meann]))/len(stroki))
# Out:
# [[ 23891     25      7]
#  [ 94746     10      6]
#  [ 67660      5      6]
#  ...
#  [371794     35      8]
#  [ 43407     35      7]
#  [370915      5      4]]
# Процент рецептов, кол-во ингредиентов в которых меньше среднего
# 58.989

# %% [markdown]
# 12. Назовем "простым" такой рецепт, длительность выполнения которого не больше 20 минут и кол-во ингредиентов в котором не больше 5. Создайте версию датасета с дополнительным столбцом, значениями которого являются 1, если рецепт простой, и 0 в противном случае.

# %%
new_stroki = np.append(stroki, np.zeros((stroki.shape[0],1), dtype = 'int32'), axis = 1)
new_stroki[np.logical_and(new_stroki[:,1]<=20,new_stroki[:,2]<=5)] = 1
new_stroki = new_stroki.copy()
print(new_stroki)
# Out:
# [[127244     60     16      0]
#  [ 23891     25      7      0]
#  [ 94746     10      6      0]
#  ...
#  [498432     65     15      0]
#  [     1      1      1      1]
#  [ 81993    140     14      0]]

# %% [markdown]
# 13. Выведите процент "простых" рецептов в датасете

# %%
print((100*len(new_stroki[new_stroki[:,3] == 1]))/len(stroki))
# Out:
# 9.943

# %% [markdown]
# 14. Разделим рецепты на группы по следующему правилу. Назовем рецепты короткими, если их продолжительность составляет менее 10 минут; стандартными, если их продолжительность составляет более 10, но менее 20 минут; и длинными, если их продолжительность составляет не менее 20 минут. Создайте трехмерный массив, где нулевая ось отвечает за номер группы (короткий, стандартный или длинный рецепт), первая ось - за сам рецепт и вторая ось - за характеристики рецепта. Выберите максимальное количество рецептов из каждой группы таким образом, чтобы было возможно сформировать трехмерный массив. Выведите форму полученного массива.

# %%
g1 = stroki[stroki[:,1]<10]
g2 = stroki[np.logical_and(stroki[:,1]>=10, stroki[:,1]<20)]
g3 = stroki[stroki[:,1]>=20]
maxx = min(len(g1), len(g2), len(g3))
stroki_3d = np.array([[g1[:maxx-1],g2[:maxx-1],g3[:maxx-1]]])
print(stroki_3d)
# Out:
# [[[[ 67660      5      6]
#    [366174      7      9]
#    [204134      5      3]
#    ...
#    [     1      1      1]
#    [420725      5      3]
#    [     1      1      1]]
#
#   [[ 94746     10      6]
#    [ 33941     18      9]
#    [446597     15      5]
#    ...
#    [107094     10      4]
#    [  9831     15      7]
#    [335859     12     14]]
#
#   [[127244     60     16]
#    [ 23891     25      7]
#    [157911     60     14]
#    ...
#    [ 92137     80      9]
#    [168901     25      7]
#    [392339     35     13]]]]
